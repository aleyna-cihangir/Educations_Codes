# %% [markdown]
# #### PYTHON LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from termcolor import colored
from PIL import Image
from scipy.io import wavfile
from IPython.display import Audio

# %%
# print(colored("\033[1m" + "Uvp has how many Zero : ", "Red"), type(titanic_dataset))

# %% [markdown]
# #### TITANIC DATASET

# %%
titanic_dataset = pd.read_csv(r'C:\Users\AleynaCihangir\Desktop\MarketPlace PowerBrands Projects\000_Open_Source_Codes\train.csv')
titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(colored(type(titanic_dataset), 'red'))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
titanic_dataset.head() # show us first 5 values
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_dataset.tail() # show us last 5 values
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_dataset.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
titanic_dataset.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# **INDEXING**

# %%
titanic_dataset.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
titanic_dataset.iloc[300:306]         # start 300 finish 305
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 300          301         1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 301          302         1       3                        McCoy, Mr. Bernard
# 302          303         0       3           Johnson, Mr. William Cahoone Jr
# 303          304         1       2                       Keane, Miss. Nora A
# 304          305         0       3         Williams, Mr. Howard Hugh "Harry"
# 305          306         1       1            Allison, Master. Hudson Trevor
#
#         Sex    Age  SibSp  Parch    Ticket    Fare    Cabin Embarked
# 300  female    NaN      0      0      9234    7.75      NaN        Q
# 301    male    NaN      2      0    367226   23.25      NaN        Q
# 302    male  19.00      0      0      LINE    0.00      NaN        S
# 303  female    NaN      0      0    226593   12.35     E101        Q
# 304    male    NaN      0      0  A/5 2466    8.05      NaN        S
# ...

# %%
titanic_dataset.loc[255:262, 'Ticket']      # first show us index and second part show us ticket numbers
# Out:
# 255        2650
# 256    PC 17585
# 257      110152
# 258    PC 17755
# 259      230433
# 260      384461
# 261      347077
# 262      110413
# Name: Ticket, dtype: object

# %%
titanic_dataset['Sex'].head() # select a column and show first 5 values
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
titanic_dataset[['Name', 'Age']].head() # select columns and show first 5 values
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %% [markdown]
# **SELECTIONS**

# %%
titanic_dataset[titanic_dataset['Age'] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
titanic_dataset['Age'] > 70 # returns just boolean
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic_dataset[(titanic_dataset['Age'] == 11) | (titanic_dataset['Age'] == 55) ]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 15            16         1       2     Hewlett, Mrs. (Mary D Kingcome)
# 59            60         0       3   Goodwin, Master. William Frederick
# 492          493         0       1           Molson, Mr. Harry Markland
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 15   female  55.0      0      0   248706   16.0000      NaN        S
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 492    male  55.0      0      0   113787   30.5000      C30        S
# 542  female  11.0      4      2   347082   31.2750      NaN        S
# 731    male  11.0      0      0     2699   18.7875      NaN        C
# ...

# %%
titanic_dataset['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# **VISULATION**

# %%
titanic_dataset.plot(title='Line Plot');

# %%
titanic_dataset.plot(title='Line Plot', legend=False);

# %%
titanic_dataset.plot(title='Line Plot', legend=False, figsize=(15,6));

# %%
titanic_dataset.plot(x= 'Age', y='Fare', title='Line Plot', legend=False, figsize=(15,6)); # just for numeric datas

# %%
titanic_dataset.plot(title='Line Plot', style='.', figsize=(15,6));

# %%
titanic_dataset.plot(title='Line Plot', kind='scatter',x ='Age', y='Pclass', figsize=(15,6));

# %%
titanic_dataset.plot(title='Line Plot', kind='hist',y='Age', bins=50, figsize=(15,6), alpha=0.6);

# %%
titanic_dataset.plot(title='Box Plot', kind='box', figsize=(15,6))
# Out:
# <AxesSubplot:title={'center':'Box Plot'}>

# %%
fig, ax = plt.subplots(2,2, figsize=(20,10))
titanic_dataset.plot(ax=ax[0][0], title='Line Plot');
titanic_dataset.plot(ax=ax[0][1], style='o', title='Scatter Plot');
titanic_dataset.plot(ax=ax[1][0], kind='hist', bins=50, title='Histogram');
titanic_dataset.plot(ax=ax[1][1], kind='box', title='Bos Plot');

# %%
gt01 = titanic_dataset['Age'] > 35
piecounts = gt01.value_counts()
piecounts
# Out:
# False    674
# True     217
# Name: Age, dtype: int64

# %%
piecounts.plot(kind='pie', figsize=(5,5), explode=[0, 0.15], autopct='%1.1f%%', shadow=True, startangle=90, fontsize=16);

# %% [markdown]
# #### IMAGES and SOUND

# %%
img = Image.open(r'C:\Users\AleynaCihangir\Desktop\ISS\ISS_ESA331421.jpg')
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imgarray = np.asarray(img)
imgarray.shape
# Out:
# (2810, 4250, 3)

# %%
imgarray.ravel().shape
# Out:
# (35827500,)

# %%
rate, snd = wavfile.read(filename=r'C:\Users\AleynaCihangir\Desktop\ISS\chord.wav')
Audio(data=snd, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(snd)
# Out:
# 24231

# %%
plt.plot(snd);
